# %% [markdown]
# <a href="https://colab.research.google.com/github/GonzaOrtiz85/APRENDIZAJE_AUTOMATICO_2026/blob/main/Actividad_1_clase4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/sample_data/salary_data.csv")
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes
# None
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
X = df[["YearsExperience"]]
y = df["Salary"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()
modelo.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = modelo.predict(X_test)
print(y_pred)
# Out:
# [ 45579.66394575 108287.17317425 123262.1007512   64298.32341695
#   74593.5861261   90504.44667662]

# %%
from sklearn import metrics

print("Error absoluto:", metrics.mean_absolute_error(y_test, y_pred))
print("R2:", metrics.r2_score(y_test, y_pred))
# Out:
# Error absoluto: 3728.6757315232776
# R2: 0.9686717064555268

# %% [markdown]
# **R2 cerca de 1 → modelo bueno**

# %%
import matplotlib.pyplot as plt

plt.scatter(X, y)
plt.plot(X_test, y_pred, color="red")
plt.xlabel("Años de experiencia")
plt.ylabel("Salario")
plt.title("Regresión lineal")
plt.show()

# %% [markdown]
# A medida que aumentan los años de experiencia, el salario sube
