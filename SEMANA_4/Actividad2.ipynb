# %% [markdown]
# <a href="https://colab.research.google.com/github/GonzaOrtiz85/APRENDIZAJE_AUTOMATICO_2026/blob/main/Actividad2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/sample_data/usuarios_win_mac_lin.csv")
df.head()
# Out:
#    duracion  paginas  acciones  valor  clase
# 0       7.0        2         4      8      2
# 1      21.0        2         6      6      2
# 2      57.0        2         4      4      2
# 3     101.0        3         6     12      2
# 4     109.0        2         6     12      2

# %%
X = df[["duracion", "paginas", "acciones", "valor"]]
y = df["clase"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

modelo = LogisticRegression(max_iter=1000)
modelo.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = modelo.predict(X_test)
print(y_pred)
# Out:
# [2 0 2 2 2 0 2 1 0 2 2 2 0 2 0 1 1 0 1 2 2 0 2 2 2 2 1 1 0 0 0 2 0 0]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.67      0.74        15
#            1       0.50      0.60      0.55         5
#            2       0.88      1.00      0.93        14
#
#     accuracy                           0.79        34
#    macro avg       0.74      0.76      0.74        34
# weighted avg       0.80      0.79      0.79        34
