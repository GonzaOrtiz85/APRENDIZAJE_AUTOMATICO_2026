# %% [markdown]
# <a href="https://colab.research.google.com/github/GonzaOrtiz85/APRENDIZAJE_AUTOMATICO_2026/blob/main/Semana2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Actividad Pandas – Importación de datos
#
# En esta actividad se trabaja con la librería Pandas para importar datos desde distintos formatos: CSV, JSON y Excel.

# %%
import pandas as pd

# %% [markdown]
# ### 1. Carga de los archivos

# %%
import pandas as pd

# 1. Cargar ventas.csv
ventas = pd.read_csv("C:/Users/ASUS/Desktop/2026 CS DATOS E INTELIGENCIA ARTIFICIAL/APRENDIZAJE AUTOMATICO/archivos semana 2/ventas (1).csv")
print(ventas.head())

# 2. Cargar clientes.json
clientes = pd.read_json("C:/Users/ASUS/Desktop/2026 CS DATOS E INTELIGENCIA ARTIFICIAL/APRENDIZAJE AUTOMATICO/archivos semana 2/clientes.json")
print("\nCantidad total de clientes:")
print(len(clientes))

# 3. Cargar inventario.xlsx
inventario = pd.read_excel("C:/Users/ASUS/Desktop/2026 CS DATOS E INTELIGENCIA ARTIFICIAL/APRENDIZAJE AUTOMATICO/archivos semana 2/inventario.xlsx")
print("\nPromedio de stock disponible:")
print(inventario["stock"].mean())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_16271/3237951252.py in <cell line: 0>()
#       2
#       3 # 1. Cargar ventas.csv
# ----> 4 ventas = pd.read_csv("C:/Users/ASUS/Desktop/2026 CS DATOS E INTELIGENCIA ARTIFICIAL/APRENDIZAJE AUTOMATICO/archivos semana 2/ventas (1).csv")
#       5 print(ventas.head())
#       6
#
# ...

# %% [markdown]
# Reformulé, decidí subir los archivos a la carpeta de archivos de Colab para facilitar la carga

# %%
import pandas as pd

ventas = pd.read_csv("ventas (1).csv")
print(ventas.head())
# Out:
#    id_venta       fecha  producto  cantidad  precio_unitario
# 0         1  2026-01-10  Notebook         2             1200
# 1         2  2026-01-12     Mouse         5               25
# 2         3  2026-01-15   Teclado         3               45
# 3         4  2026-01-18   Monitor         1              300

# %% [markdown]
# ### 2. Carga de archivo JSON (clientes)

# %%
clientes = pd.read_json("clientes.json")
print(clientes.head())
print("Cantidad total de clientes:", len(clientes))
# Out:
#    id_cliente        nombre             email   telefono
# 0           1    Juan Pérez    juan@email.com  123456789
# 1           2   María López   maria@email.com  987654321
# 2           3  Carlos Gómez  carlos@email.com  456123789
# Cantidad total de clientes: 3

# %% [markdown]
# ### 3. Carga de archivo Excel (inventario)

# %%
inventario = pd.read_excel("inventario.xlsx")
print(inventario.head())
print(inventario.columns)
# Out:
#    id_producto    nombre    categoria  stock  precio
# 0            1  Notebook  Electrónica     10    1200
# 1            2     Mouse   Accesorios     50      25
# 2            3   Teclado   Accesorios     30      45
# 3            4   Monitor  Electrónica     15     300
# Index(['id_producto', 'nombre', 'categoria', 'stock', 'precio'], dtype='object')

# %%
datos_combinados = pd.concat([ventas, clientes], axis=0)

print(datos_combinados.head())
# Out:
#    id_venta       fecha  producto  cantidad  precio_unitario  id_cliente  \
# 0       1.0  2026-01-10  Notebook       2.0           1200.0         NaN
# 1       2.0  2026-01-12     Mouse       5.0             25.0         NaN
# 2       3.0  2026-01-15   Teclado       3.0             45.0         NaN
# 3       4.0  2026-01-18   Monitor       1.0            300.0         NaN
# 0       NaN         NaN       NaN       NaN              NaN         1.0
#
#        nombre           email     telefono
# 0         NaN             NaN          NaN
# 1         NaN             NaN          NaN
# 2         NaN             NaN          NaN
# 3         NaN             NaN          NaN
# 0  Juan Pérez  juan@email.com  123456789.0
